# %% [markdown]
# # Task 1

# %% [markdown]
# Imorting all necessaries libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# Importing the dataset

# %%
df=pd.read_csv("creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# Checking whether there is missing values are there or not

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1081

# %%
df = df.drop_duplicates( keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 283726 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    283726 non-null  float64
#  1   V1      283726 non-null  float64
#  2   V2      283726 non-null  float64
#  3   V3      283726 non-null  float64
#  4   V4      283726 non-null  float64
#  5   V5      283726 non-null  float64
#  6   V6      283726 non-null  float64
#  7   V7      283726 non-null  float64
#  8   V8      283726 non-null  float64
#  9   V9      283726 non-null  float64
#  10  V10     283726 non-null  float64
#  11  V11     283726 non-null  float64
#  12  V12     283726 non-null  float64
#  13  V13     283726 non-null  float64
#  14  V14     283726 non-null  float64
#  15  V15     283726 non-null  float64
#  16  V16     283726 non-null  float64
#  17  V17     283726 non-null  float64
#  18  V18     283726 non-null  float64
#  19  V19     283726 non-null  float64
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %% [markdown]
# this data set is higly unbalanced
# #0 represents leg trans(means its real and legal)
# #1 represents fraud trans(means its fraud detection)

# %%
leg =df[df.Class == 0]
fraud =df[df.Class == 1]

# %%
print(leg.shape)
print(fraud.shape)
# Out:
# (283253, 31)
# (473, 31)

# %%
leg.Amount.describe()
# Out:
# count    283253.000000
# mean         88.413575
# std         250.379023
# min           0.000000
# 25%           5.670000
# 50%          22.000000
# 75%          77.460000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     473.000000
# mean      123.871860
# std       260.211041
# min         0.000000
# 25%         1.000000
# 50%         9.820000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# #Compares the values for both trans

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94835.058093  0.013439 -0.009829  0.012853 -0.010440  0.006769
# 1      80450.513742 -4.498280  3.405965 -6.729599  4.472591 -2.957197
#
#              V6        V7        V8        V9  ...       V20      V21  \
# Class                                          ...
# 0      0.001251  0.010447 -0.002448  0.002613  ... -0.000489 -0.00115
# 1     -1.432518 -5.175912  0.953255 -2.522124  ...  0.405043  0.46655
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000160  0.000360  0.000393 -0.000301  0.000065  0.001409  0.000418
# 1      0.086639 -0.096464 -0.106643  0.040615  0.050456  0.213774  0.078270
#
#            Amount
# Class
# 0       88.413575
# 1      123.871860
#
# [2 rows x 30 columns]

# %%
leg_sample = leg.sample(n=492)

# %%
new_data = pd.concat([leg_sample, fraud], axis=0)

# %%
new_data.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     965.000000  965.000000  965.000000  965.000000  965.000000
# mean    86698.900518   -2.207130    1.654264   -3.291069    2.188336
# std     48146.336911    5.281761    3.495904    5.991886    3.181324
# min       357.000000  -30.552380   -8.402154  -31.103685   -3.960666
# 25%     42814.000000   -2.564829   -0.169682   -4.871394   -0.153780
# 50%     78795.000000   -0.738440    0.942289   -1.248421    1.297141
# 75%    133839.000000    1.033342    2.617105    0.343398    4.173268
# max    171734.000000    2.320537   22.057729    4.226108   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  965.000000  965.000000  965.000000  965.000000  965.000000  ...
# mean    -1.390373   -0.621099   -2.565198    0.527426   -1.268570  ...
# std      4.134231    1.821787    5.506841    3.968185    2.275274  ...
# ...

# %%
new_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 68416    52982.0 -0.334621  1.265677  0.724249  0.489746  0.057364 -0.553142
# 260603  159633.0  2.219230 -0.895200 -0.577188 -0.995368 -0.854159 -0.351116
# 162220  114939.0 -0.532709  0.609033  0.785754 -1.411946  0.586715  0.702840
# 117617   74742.0 -0.924420  0.173111  1.951726 -0.986045 -0.156362 -0.832316
# 254808  156922.0  2.243919 -1.546316 -0.733993 -1.837723 -1.099636  0.361471
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 68416   0.394307  0.266543 -0.684721  ...  0.088293  0.209083 -0.079088
# 260603 -1.054575 -0.127142  0.016653  ...  0.364392  1.190483  0.050950
# 162220  0.188854  0.269534  0.641497  ... -0.225480 -0.570252 -0.124958
# 117617  1.212586 -0.246345  0.096882  ... -0.210408 -0.736699  0.010930
# 254808 -1.542724  0.160418 -1.169543  ... -0.389954 -0.744395  0.408956
#
# ...

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    473
# Name: count, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      92705.987805 -0.004459 -0.029790  0.014672 -0.007706  0.115943
# 1      80450.513742 -4.498280  3.405965 -6.729599  4.472591 -2.957197
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.158985 -0.055305  0.118041 -0.063425  ...  0.008527 -0.002029
# 1     -1.432518 -5.175912  0.953255 -2.522124  ...  0.405043  0.466550
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.001071 -0.095286 -0.004503 -0.005628 -0.017991 -0.010587  0.015915
# 1      0.086639 -0.096464 -0.106643  0.040615  0.050456  0.213774  0.078270
#
#            Amount
# Class
# 0       87.676951
# 1      123.871860
#
# [2 rows x 30 columns]

# %%
df1= new_data.drop(columns='Class', axis=1)

# %%
df1
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 68416    52982.0 -0.334621  1.265677  0.724249  0.489746  0.057364 -0.553142
# 260603  159633.0  2.219230 -0.895200 -0.577188 -0.995368 -0.854159 -0.351116
# 162220  114939.0 -0.532709  0.609033  0.785754 -1.411946  0.586715  0.702840
# 117617   74742.0 -0.924420  0.173111  1.951726 -0.986045 -0.156362 -0.832316
# 254808  156922.0  2.243919 -1.546316 -0.733993 -1.837723 -1.099636  0.361471
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
df2 = new_data['Class']

# %%
df2
# Out:
# 68416     0
# 260603    0
# 162220    0
# 117617    0
# 254808    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 965, dtype: int64

# %% [markdown]
# Model Building

# %%
df1_train,df1_test,df2_train,df2_test=train_test_split(df1,df2,test_size=0.3,random_state=123)

# %% [markdown]
# Logistic Regrssion

# %%
lr=LogisticRegression()
model2=lr.fit(df1_train,df2_train)
prediction2=model2.predict(df1_test)
accuracy_score(df2_test,prediction2)
# Out:
# 0.9448275862068966

# %% [markdown]
# Model 2

# %%
dff1= new_data.drop(columns='Class', axis=1)

# %%
dff2 = new_data['Class']

# %%
dff1_train,dff1_test,dff2_train,dff2_test=train_test_split(dff1,dff2,test_size=0.30,random_state=123)

# %% [markdown]
# Random forest

# %%
rfc=RandomForestClassifier()
model=rfc.fit(dff1_train,dff2_train)
prediction=model.predict(dff1_test)
accuracy_score(dff2_test,prediction)
# Out:
# 0.9413793103448276

# %% [markdown]
# Model 3

# %%
dfff1= new_data.drop(columns='Class', axis=1)

# %%
dfff2 = new_data['Class']

# %%
dfff1_train,dfff1_test,dfff2_train,dfff2_test=train_test_split(dfff1,dfff2,test_size=0.30,random_state=123)

# %%
scaler = MinMaxScaler()

X_train = scaler.fit_transform(dfff1_train)
X_test = scaler.fit_transform(dfff1_test)

X_test
# Out:
# array([[0.69571815, 0.90379599, 0.192852  , ..., 0.66873977, 0.57071702,
#         0.01594141],
#        [0.84124019, 1.        , 0.13962655, ..., 0.65230978, 0.53971098,
#         0.01135185],
#        [0.4077909 , 0.90297734, 0.24819593, ..., 0.68435917, 0.59047753,
#         0.00646323],
#        ...,
#        [0.44109544, 0.76894818, 0.32165698, ..., 0.67090471, 0.74645015,
#         0.0609704 ],
#        [0.72567239, 0.93843229, 0.22147773, ..., 0.48160196, 0.33929825,
#         0.00109246],
#        [0.14410371, 0.96582362, 0.23984857, ..., 0.64769486, 0.57303961,
#         0.00190418]])

# %%
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)

# %% [markdown]
# KNN

# %%
knn= KNeighborsClassifier()
knn.fit(X_train,dfff2_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(X_train, dfff2_train)
# Out:
# 0.9362962962962963

# %%
prediction=knn.predict(X_test)
accuracy_score(dfff2_test,prediction)
# Out:
# 0.9310344827586207

# %% [markdown]
# we can see that all the three above models are working fine with that high accuracy rate
